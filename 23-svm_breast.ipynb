# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 乳腺癌诊断分类

# %% [markdown]
# ### 加载、探索数据

# %%
df = pd.read_csv('./data/breast_cancer_data-master/data.csv')
pd.set_option('max_columns',30)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
features_mean = list(df.columns[2:12])
features_se = list(df.columns[12:22])
features_worst = list(df.columns[22:32])

# %%
# 删除无用列，替换目标值
df1 = df.drop(labels='id',axis=1)
df1['diagnosis']=df1['diagnosis'].map({'M':1,'B':0})
df1
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ### 数据可视化

# %%
df1['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
sns.countplot(df1['diagnosis'])

# %%
corr = df1[features_mean].corr()
corr
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                1.000000      0.323782        0.997855   0.987357
# texture_mean               0.323782      1.000000        0.329533   0.321086
# perimeter_mean             0.997855      0.329533        1.000000   0.986507
# area_mean                  0.987357      0.321086        0.986507   1.000000
# smoothness_mean            0.170581     -0.023389        0.207278   0.177028
# compactness_mean           0.506124      0.236702        0.556936   0.498502
# concavity_mean             0.676764      0.302418        0.716136   0.685983
# concave points_mean        0.822529      0.293464        0.850977   0.823269
# symmetry_mean              0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean    -0.311631     -0.076437       -0.261477  -0.283110
#
#                         smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()

# %%
print(features_mean)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']

# %%
# 特征选择
features_remain = ['radius_mean','texture_mean','smoothness_mean','concavity_mean', 'symmetry_mean', 'fractal_dimension_mean']

# %%
# 规划化数据
df1[features_remain]
# Out:
#      radius_mean  texture_mean  smoothness_mean  concavity_mean  \
# 0          17.99         10.38          0.11840         0.30010
# 1          20.57         17.77          0.08474         0.08690
# 2          19.69         21.25          0.10960         0.19740
# 3          11.42         20.38          0.14250         0.24140
# 4          20.29         14.34          0.10030         0.19800
# ..           ...           ...              ...             ...
# 564        21.56         22.39          0.11100         0.24390
# 565        20.13         28.25          0.09780         0.14400
# 566        16.60         28.08          0.08455         0.09251
# 567        20.60         29.33          0.11780         0.35140
# 568         7.76         24.54          0.05263         0.00000
#
#      symmetry_mean  fractal_dimension_mean
# 0           0.2419                 0.07871
# 1           0.1812                 0.05667
# 2           0.2069                 0.05999
# ...

# %%
ss = StandardScaler()

# %%
X = pd.DataFrame(ss.fit_transform(df1[features_remain]),columns=features_remain)
X
# Out:
#      radius_mean  texture_mean  smoothness_mean  concavity_mean  \
# 0       1.097064     -2.073335         1.568466        2.652874
# 1       1.829821     -0.353632        -0.826962       -0.023846
# 2       1.579888      0.456187         0.942210        1.363478
# 3      -0.768909      0.253732         3.283553        1.915897
# 4       1.750297     -1.151816         0.280372        1.371011
# ..           ...           ...              ...             ...
# 564     2.110995      0.721473         1.041842        1.947285
# 565     1.704854      2.085134         0.102458        0.693043
# 566     0.702284      2.045574        -0.840484        0.046588
# 567     1.838341      2.336457         1.525767        3.296944
# 568    -1.808401      1.221792        -3.112085       -1.114873
#
#      symmetry_mean  fractal_dimension_mean
# 0         2.217515                2.255747
# 1         0.001392               -0.868652
# 2         0.939685               -0.398008
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df1['diagnosis'], test_size=0.33, random_state=42)

# %%
# 创建SVM
mlsvm = svm.SVC()
mlsvm.fit(X_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pre = mlsvm.predict(X_test)

# %%
print("混淆矩阵:")
print(metrics.confusion_matrix(y_test,y_pre))
print("效果评估:")
print(metrics.classification_report(y_test,y_pre))
# Out:
# 混淆矩阵:
# [[120   1]
#  [  5  62]]
# 效果评估:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       121
#            1       0.98      0.93      0.95        67
#
#     accuracy                           0.97       188
#    macro avg       0.97      0.96      0.96       188
# weighted avg       0.97      0.97      0.97       188

# %% [markdown]
# ### 采用十个特征的

# %%
X = pd.DataFrame(ss.fit_transform(df1[features_mean]),columns=features_mean)
X_train, X_test, y_train, y_test = train_test_split(X, df1['diagnosis'], test_size=0.33, random_state=42)
# 创建SVM
mlsvm = svm.SVC()
mlsvm.fit(X_train,y_train)
y_pre = mlsvm.predict(X_test)
print("混淆矩阵:")
print(metrics.confusion_matrix(y_test,y_pre))
print("效果评估:")
print(metrics.classification_report(y_test,y_pre))
# Out:
# 混淆矩阵:
# [[119   2]
#  [  6  61]]
# 效果评估:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       121
#            1       0.97      0.91      0.94        67
#
#     accuracy                           0.96       188
#    macro avg       0.96      0.95      0.95       188
# weighted avg       0.96      0.96      0.96       188
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# ### 换模型--决策树

# %%
from sklearn import tree

# %%
mltree = tree.DecisionTreeClassifier()
mltree.fit(X_train,y_train)
y_pre = mltree.predict(X_test)
print("混淆矩阵:")
print(metrics.confusion_matrix(y_test,y_pre))
print("效果评估:")
print(metrics.classification_report(y_test,y_pre))
# Out:
# 混淆矩阵:
# [[107  14]
#  [  4  63]]
# 效果评估:
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92       121
#            1       0.82      0.94      0.88        67
#
#     accuracy                           0.90       188
#    macro avg       0.89      0.91      0.90       188
# weighted avg       0.91      0.90      0.91       188
